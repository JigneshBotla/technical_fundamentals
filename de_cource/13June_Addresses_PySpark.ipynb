# %%
df1 = spark.read.format('csv').option('header','true').option('delimiter','\t').load('/Volumes/gizmobox/landing/operational_data/addresses/')
display(df1)

# %%
df1.writeTo('gizmobox.bronze.py_addresses').createOrReplace()
