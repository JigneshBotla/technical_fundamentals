# %%
# %sql
select * from gizmobox.bronze.v_memberships

# %%
# %sql
select cast(split(element_at(split(path, "/"), -1),".png")[0] as bigint) as customer_id, path, modificationTime, length, content from gizmobox.bronze.v_memberships

# %%
# %sql
select cast(regexp_extract(path, '.*/([0-9]+).png$',1) as bigint) as customer_id,path, modificationTime, length, content membership_card from gizmobox.bronze.v_memberships

# %%
# %sql
create or replace table gizmobox.silver.memberships as 
select cast(regexp_extract(path, '.*/([0-9]+).png$',1) as bigint) as customer_id,content as membership_card from gizmobox.bronze.v_memberships

# %%
# %sql
select * from gizmobox.silver.memberships
