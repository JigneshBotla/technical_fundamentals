# %%
df = spark.sql("Select * from gizmobox.bronze.payments")
display(df)

# %% [markdown]
# ## DF Reader API

# %%
df1 = spark.read.format('json').load("/Volumes/gizmobox/landing/operational_data/customers")
display(df1)

# %% [markdown]
# ## spark.table function

# %%
df2 = spark.table('gizmobox.bronze.v_customers')
display(df2)
