# %%
payment_schema = 'payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payent_method STRING'

# %%
df1 = spark.read.format("csv").schema(payment_schema).load("s3://decoursejignesh/external_data/payments/")
display(df1)

# %%
df1.writeTo('gizmobox.bronze.py_payments').createOrReplace()
