# %%
# %fs ls '/Volumes/gizmobox/landing/operational_data/memberships'

# %%
# %sql
select * from binaryFile.`/Volumes/gizmobox/landing/operational_data/memberships/*/*.png`

# %%
# %sql
create or replace view gizmobox.bronze.v_memberships as 
select * from binaryFile.`/Volumes/gizmobox/landing/operational_data/memberships/*/*.png`

# %%
# %sql
select * from gizmobox.bronze.v_memberships;

# %%
# %sql
CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments
(payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_staus INTEGER, payment_method STRING)
USING CSV
OPTIONS (
header = "true",
delimiter = ","
)
LOCATION "s3://decoursejignesh/external_data/payments/"

# %%
# %sql
select * from gizmobox.bronze.payments;

# %%
# %sql
DESC EXTENDED gizmobox.bronze.payments;
DESC EXTENDED gizmobox.bronze.v_customers;

# %%
# %sql
select * from gizmobox.bronze.payments;

# %%
# %sql
REFRESH TABLE gizmobox.bronze.payments;
